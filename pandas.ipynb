# %% [markdown]
# <a href="https://colab.research.google.com/github/naseemfiver/intro_sentimental_analysis/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#data loading
#df = pd.read_csv('/content/drive/MyDrive/pandas-master/pokemon_data.txt',delimiter='\t')
#df = pd.read_excel('/content/drive/MyDrive/pandas-master/pokemon_data.xlsx')
df = pd.read_csv('/content/drive/MyDrive/pandas-master/pokemon_data.csv')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Reading data in pandas

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#print(df[['Name','Type 2']][0:5])
#df.Name[0:5]
i=0
print(df[[x for x in df.columns ]][0:5])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#print(df.iloc[3])

# %%
for index,a in df.iterrows():
  print(index,a['Type 1'])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
for index, row in df.iterrows():
  print(index,row['Name'] )
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
 df.loc[df['Legendary']==True]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 794  718     Zygarde50% Forme    Dragon    Ground    600  108     100
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
df.describe()
# Out:
#                #       Total          HP      Attack     Defense     Sp. Atk  \
# count  738.00000  738.000000  738.000000  738.000000  738.000000  738.000000
# mean   367.45393  435.158537   69.081301   79.040650   73.960705   72.733062
# std    208.07444  120.519108   25.532407   32.432014   31.568492   32.760436
# min      2.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    192.25000  330.000000   50.000000   55.000000   50.000000   48.000000
# 50%    372.50000  450.000000   65.000000   75.000000   70.000000   65.000000
# 75%    546.75000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    721.00000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  738.000000  738.000000  738.000000
# mean    71.674797   68.668022    3.356369
# std     27.823146   29.798137    1.664244
# min     20.000000    5.000000    1.000000
# 25%     50.000000   48.000000    2.000000
# ...

# %%
df.sort_values(["Name",'HP'], ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df['HP']+df['Attack']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
#df = df.drop(columns = ['Total'])
#df

df['Total'] = df.iloc[:,4:10].sum(axis =1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
#df = df[['Total','HP','Defense']]
#df.head()

# %%
cols = list(df.columns.values)
df = df[cols[:4]+[cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df = df.drop(df.index[df['Speed'].isin([45])])
df
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 1      2                    Ivysaur    Grass  Poison    405   60      62
# 4      4                 Charmander     Fire     NaN    309   39      52
# 6      6                  Charizard     Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# ..   ...                        ...      ...     ...    ...  ...     ...
# 794  718           Zygarde50% Forme   Dragon  Ground    600  108     100
# 795  719                    Diancie     Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
